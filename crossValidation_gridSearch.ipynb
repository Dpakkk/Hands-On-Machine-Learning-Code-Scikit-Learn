# %%
import mglearn
mglearn.plots.plot_cross_val_selection()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /var/folders/ck/22v0x0pj3rvchfgdwdpklf5h0000gn/T/ipykernel_89574/1246862868.py in <module>
#       1 import mglearn
# ----> 2 mglearn.plots.plot_cross_val_selection()
#
# ~/opt/anaconda3/lib/python3.9/site-packages/mglearn/plot_grid_search.py in plot_cross_val_selection()
#      35                                     markeredgewidth=3)
#      36
# ---> 37     plt.xticks(range(len(results)), [str(x).strip("{}").replace("'", "") for x
#      38                                      in grid_search.cv_results_['params']],
#      39                rotation=90)
#
# ~/opt/anaconda3/lib/python3.9/site-packages/matplotlib/pyplot.py in xticks(ticks, labels, **kwargs)
#    1812         labels = ax.get_xticklabels()
#    1813     else:
# -> 1814         labels = ax.set_xticklabels(labels, **kwargs)
#    1815     for l in labels:
# ...

# %%
mglearn.plots.plot_grid_search_overview()
